# %% [markdown]
# # ML Models on Timbre Data

# %% [markdown]
# ## Loading more or less clean data

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_timbre = pd.read_csv('TimbreAll_withFeatures.csv')
df_timbre.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  timbre_all_1  \
# 0           0             0     51.416218
# 1           1             1     46.061457
# 2           2             2     49.410781
# 3           3             3     50.752320
# 4           4             4     46.626136
#
#                                         timbre_all_2  \
# 0  [-159.534, -165.043, -178.349, -142.676, -189....
# 1  [61.193, 23.859, 131.734, 51.307, 76.377, 80.5...
# 2  [171.13, -281.075, -233.169, -225.21, -227.325...
# 3  [171.13, -195.806, -193.59, -170.1, -167.181, ...
# 4  [159.754, 6.762, 94.103, -111.062, -59.981, -3...
#
#                                         timbre_all_3  \
# 0  [-54.943, -26.554, -31.161, -81.025, -38.769, ...
# 1  [-4.064, 32.899, 91.34, 91.189, 22.277, 54.533...
# 2  [9.469, -33.326, -4.326, 3.887, -26.942, 1.06,...
# 3  [9.469, -133.475, -119.206, -137.978, -142.693...
# 4  [8.207, -81.832, -84.982, -57.909, -23.983, -3...
#
#                                         timbre_all_4  \
# 0  [219.73, 203.264, 176.276, 246.162, 196.86, 19...
# 1  [76.322, -6.545, 140.95, -44.779, 145.741, -16...
# 2  [-28.48, -23.372, 3.01, -26.154, -14.353, -50....
# 3  [-28.48, 52.066, 38.154, 46.209, 74.23, 59.929...
# 4  [-42.077, 3.164, 84.048, -23.975, -99.476, -68...
#
#                                         timbre_all_5  \
# 0  [49.002, 53.621, 23.53, 32.439, 14.445, 8.525,...
# 1  [71.732, 27.104, 24.14, 30.428, 29.539, 27.608...
# 2  [57.491, 62.867, 71.13, 73.155, 75.501, 73.369...
# 3  [57.491, 13.709, 13.49, 31.499, 23.558, 35.115...
# 4  [59.646, 18.042, -3.015, 57.9, 53.619, 38.577,...
#
#                                         timbre_all_6  \
# 0  [-113.6, -74.093, -93.638, -110.733, -105.977,...
# 1  [137.368, -4.067, -80.268, 21.022, -84.133, 4....
# 2  [-50.067, -21.341, -40.282, -58.064, -75.817, ...
# 3  [-50.067, -55.298, -62.962, 18.922, -8.448, 0....
# 4  [-52.861, 86.289, 52.594, -29.84, 31.085, -2.6...
#
#                                         timbre_all_7  \
# 0  [-69.729, -44.686, -53.704, -46.389, -28.113, ...
# 1  [-10.241, -62.677, -27.507, -26.072, -55.701, ...
# 2  [14.833, -20.045, -6.414, 6.812, -15.308, 15.3...
# 3  [14.833, -31.337, -30.616, -21.809, -27.419, -...
# 4  [13.376, -33.908, -18.697, -27.57, -13.75, -2....
#
#                                         timbre_all_8          ...            \
# 0  [-22.161, -20.58, -48.763, -22.934, -2.973, -4...          ...
# 1  [-13.244, 7.293, 4.592, -31.924, -30.91, 10.58...          ...
# 2  [5.359, 19.43, 20.342, 1.763, 7.714, 4.769, 14...          ...
# 3  [5.359, 15.383, -3.89, 17.372, 2.687, 29.89, 1...          ...
# 4  [-12.493, -55.516, 10.703, 1.01, 47.941, -15.1...          ...
#
#   max_timbre11 range_timbre11 80Percentile_timbre11 mean_timbre12  \
# 0     -100.251            0.0                3.6902     -3.411885
# 1     -112.977            0.0                1.6932     -2.246651
# 2     -113.259            0.0                0.6802      1.795072
# 3      -74.025            0.0                5.5830      0.437129
# 4      -90.895            0.0                6.8418     -6.117562
#
#    median_timbre12  std_timbre12  min_timbre12  max_timbre12  range_timbre12  \
# 0          -2.4790     13.339611       -53.845       -53.845             0.0
# 1          -2.4420     15.645132       -44.506       -44.506             0.0
# 2           1.9440     13.292210       -37.643       -37.643             0.0
# 3           1.1040     17.708769       -48.071       -48.071             0.0
# 4          -5.8825     15.538641       -57.848       -57.848             0.0
#
#    80Percentile_timbre12
# 0                 7.7588
# 1                11.5428
# 2                12.8920
# 3                16.3770
# 4                 7.0520
#
# [5 rows x 98 columns]

# %%
df_timbre.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'timbre_all_1', 'timbre_all_2',
#        'timbre_all_3', 'timbre_all_4', 'timbre_all_5', 'timbre_all_6',
#        'timbre_all_7', 'timbre_all_8', 'timbre_all_9', 'timbre_all_10',
#        'timbre_all_11', 'timbre_all_12', 'mean_timbre1', 'median_timbre1',
#        'std_timbre1', 'min_timbre1', 'max_timbre1', 'range_timbre1',
#        '80Percentile_timbre1', 'mean_timbre2', 'median_timbre2', 'std_timbre2',
#        'min_timbre2', 'max_timbre2', 'range_timbre2', '80Percentile_timbre2',
#        'mean_timbre3', 'median_timbre3', 'std_timbre3', 'min_timbre3',
#        'max_timbre3', 'range_timbre3', '80Percentile_timbre3', 'mean_timbre4',
#        'median_timbre4', 'std_timbre4', 'min_timbre4', 'max_timbre4',
#        'range_timbre4', '80Percentile_timbre4', 'mean_timbre5',
#        'median_timbre5', 'std_timbre5', 'min_timbre5', 'max_timbre5',
#        'range_timbre5', '80Percentile_timbre5', 'mean_timbre6',
#        'median_timbre6', 'std_timbre6', 'min_timbre6', 'max_timbre6',
#        'range_timbre6', '80Percentile_timbre6', 'mean_timbre7',
#        'median_timbre7', 'std_timbre7', 'min_timbre7', 'max_timbre7',
#        'range_timbre7', '80Percentile_timbre7', 'mean_timbre8',
#        'median_timbre8', 'std_timbre8', 'min_timbre8', 'max_timbre8',
#        'range_timbre8', '80Percentile_timbre8', 'mean_timbre9',
#        'median_timbre9', 'std_timbre9', 'min_timbre9', 'max_timbre9',
#        'range_timbre9', '80Percentile_timbre9', 'mean_timbre10',
#        'median_timbre10', 'std_timbre10', 'min_timbre10', 'max_timbre10',
#        'range_timbre10', '80Percentile_timbre10', 'mean_timbre11',
#        'median_timbre11', 'std_timbre11', 'min_timbre11', 'max_timbre11',
#        'range_timbre11', '80Percentile_timbre11', 'mean_timbre12',
#        'median_timbre12', 'std_timbre12', 'min_timbre12', 'max_timbre12',
#        'range_timbre12', '80Percentile_timbre12'],
#       dtype='object')

# %%
# Drop columns
df_timbre = df_timbre.drop(['Unnamed: 0', 'Unnamed: 0.1', 'timbre_all_1', 'timbre_all_2',
       'timbre_all_3', 'timbre_all_4', 'timbre_all_5', 'timbre_all_6',
       'timbre_all_7', 'timbre_all_8', 'timbre_all_9', 'timbre_all_10',
       'timbre_all_11', 'timbre_all_12'], axis=1)
df_timbre.head()
# Out:
#    mean_timbre1  median_timbre1  std_timbre1  min_timbre1  max_timbre1  \
# 0     51.416218       51.416218          0.0    51.416218    51.416218
# 1     46.061457       46.061457          0.0    46.061457    46.061457
# 2     49.410781       49.410781          0.0    49.410781    49.410781
# 3     50.752320       50.752320          0.0    50.752320    50.752320
# 4     46.626136       46.626136          0.0    46.626136    46.626136
#
#    range_timbre1  80Percentile_timbre1  mean_timbre2  median_timbre2  \
# 0            0.0             51.416218      0.789053          1.3615
# 1            0.0             46.061457     17.360664         15.8150
# 2            0.0             49.410781     35.450819         46.3010
# 3            0.0             50.752320     80.474752         94.2280
# 4            0.0             46.626136      5.873882         12.5550
#
#    std_timbre2          ...            max_timbre11  range_timbre11  \
# 0    47.407475          ...                -100.251             0.0
# 1    55.140528          ...                -112.977             0.0
# 2    71.178909          ...                -113.259             0.0
# 3    62.509153          ...                 -74.025             0.0
# 4    55.910074          ...                 -90.895             0.0
#
#    80Percentile_timbre11  mean_timbre12  median_timbre12  std_timbre12  \
# 0                 3.6902      -3.411885          -2.4790     13.339611
# 1                 1.6932      -2.246651          -2.4420     15.645132
# 2                 0.6802       1.795072           1.9440     13.292210
# 3                 5.5830       0.437129           1.1040     17.708769
# 4                 6.8418      -6.117562          -5.8825     15.538641
#
#    min_timbre12  max_timbre12  range_timbre12  80Percentile_timbre12
# 0       -53.845       -53.845             0.0                 7.7588
# 1       -44.506       -44.506             0.0                11.5428
# 2       -37.643       -37.643             0.0                12.8920
# 3       -48.071       -48.071             0.0                16.3770
# 4       -57.848       -57.848             0.0                 7.0520
#
# [5 rows x 84 columns]

# %%
df_global = pd.read_csv('cleanGlobalPrediction1.csv',encoding='latin-1')
df_global.head()
# Out:
#    Unnamed: 0                           song  \
# 0           0                   Shape of You
# 1           1                      One Dance
# 2           2                         Closer
# 3           3  Lean On (feat. MØ & DJ Snake)
# 4           4              Thinking Out Loud
#
#                                         analysis_url  \
# 0  https://api.spotify.com/v1/audio-analysis/7qiZ...
# 1  https://api.spotify.com/v1/audio-analysis/12VW...
# 2  https://api.spotify.com/v1/audio-analysis/7crM...
# 3  https://api.spotify.com/v1/audio-analysis/4vS8...
# 4  https://api.spotify.com/v1/audio-analysis/34gC...
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7qiZfU4dY1lW...
# 1  https://api.spotify.com/v1/tracks/12VWzyPDBCc8...
# 2  https://api.spotify.com/v1/tracks/7crMiinWx373...
# 3  https://api.spotify.com/v1/tracks/4vS8VaBwJJV5...
# 4  https://api.spotify.com/v1/tracks/34gCuhDGsG4b...
#
#                                     uri            artist  acousticness  \
# 0  spotify:track:7qiZfU4dY1lWllzX7mPBI3        Ed Sheeran       0.58100
# 1  spotify:track:12VWzyPDBCc8fqeWCAfNwR             Drake       0.00902
# 2  spotify:track:7crMiinWx373rNBZBaVske  The Chainsmokers       0.41500
# 3  spotify:track:4vS8VaBwJJV5Ry7UFIQuoo       Major Lazer       0.00346
# 4  spotify:track:34gCuhDGsG4bRPIf9bb02f        Ed Sheeran       0.47400
#
#    danceability  duration_ms  energy     ...      metal  pop  punk  r&b  rap  \
# 0         0.825       233713   0.652     ...          0    1     0    0    0
# 1         0.785       173987   0.617     ...          0    0     0    0    0
# 2         0.736       245507   0.541     ...          0    0     0    0    0
# 3         0.723       176561   0.809     ...          0    0     0    0    0
# 4         0.781       281560   0.445     ...          0    1     0    0    0
#
#    rock  global  global_100  global_top  popularity
# 0     0    True        True        True          92
# 1     0    True        True       False          74
# 2     0    True        True       False          65
# 3     0    True        True       False          20
# 4     0    True        True       False          87
#
# [5 rows x 36 columns]

# %%
# Define dataframe
df_raw = pd.concat([df_global, df_timbre] , axis = 1)
df_raw.head()
# Out:
#    Unnamed: 0                           song  \
# 0           0                   Shape of You
# 1           1                      One Dance
# 2           2                         Closer
# 3           3  Lean On (feat. MØ & DJ Snake)
# 4           4              Thinking Out Loud
#
#                                         analysis_url  \
# 0  https://api.spotify.com/v1/audio-analysis/7qiZ...
# 1  https://api.spotify.com/v1/audio-analysis/12VW...
# 2  https://api.spotify.com/v1/audio-analysis/7crM...
# 3  https://api.spotify.com/v1/audio-analysis/4vS8...
# 4  https://api.spotify.com/v1/audio-analysis/34gC...
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7qiZfU4dY1lW...
# 1  https://api.spotify.com/v1/tracks/12VWzyPDBCc8...
# 2  https://api.spotify.com/v1/tracks/7crMiinWx373...
# 3  https://api.spotify.com/v1/tracks/4vS8VaBwJJV5...
# 4  https://api.spotify.com/v1/tracks/34gCuhDGsG4b...
#
#                                     uri            artist  acousticness  \
# 0  spotify:track:7qiZfU4dY1lWllzX7mPBI3        Ed Sheeran       0.58100
# 1  spotify:track:12VWzyPDBCc8fqeWCAfNwR             Drake       0.00902
# 2  spotify:track:7crMiinWx373rNBZBaVske  The Chainsmokers       0.41500
# 3  spotify:track:4vS8VaBwJJV5Ry7UFIQuoo       Major Lazer       0.00346
# 4  spotify:track:34gCuhDGsG4bRPIf9bb02f        Ed Sheeran       0.47400
#
#    danceability  duration_ms  energy          ...            max_timbre11  \
# 0         0.825       233713   0.652          ...                -100.251
# 1         0.785       173987   0.617          ...                -112.977
# 2         0.736       245507   0.541          ...                -113.259
# 3         0.723       176561   0.809          ...                 -74.025
# 4         0.781       281560   0.445          ...                 -90.895
#
#    range_timbre11  80Percentile_timbre11  mean_timbre12  median_timbre12  \
# 0             0.0                 3.6902      -3.411885          -2.4790
# 1             0.0                 1.6932      -2.246651          -2.4420
# 2             0.0                 0.6802       1.795072           1.9440
# 3             0.0                 5.5830       0.437129           1.1040
# 4             0.0                 6.8418      -6.117562          -5.8825
#
#    std_timbre12  min_timbre12  max_timbre12  range_timbre12  \
# 0     13.339611       -53.845       -53.845             0.0
# 1     15.645132       -44.506       -44.506             0.0
# 2     13.292210       -37.643       -37.643             0.0
# 3     17.708769       -48.071       -48.071             0.0
# 4     15.538641       -57.848       -57.848             0.0
#
#    80Percentile_timbre12
# 0                 7.7588
# 1                11.5428
# 2                12.8920
# 3                16.3770
# 4                 7.0520
#
# [5 rows x 120 columns]

# %%
df_raw.columns
# Out:
# Index(['Unnamed: 0', 'song', 'analysis_url', 'track_href', 'uri', 'artist',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        ...
#        'max_timbre11', 'range_timbre11', '80Percentile_timbre11',
#        'mean_timbre12', 'median_timbre12', 'std_timbre12', 'min_timbre12',
#        'max_timbre12', 'range_timbre12', '80Percentile_timbre12'],
#       dtype='object', length=120)

# %%
df = df_raw.drop(['Unnamed: 0','analysis_url', 'track_href', 'uri'], axis =1)
print(df.shape)
df.head()
# Out:
# (549, 116)
#                             song            artist  acousticness  \
# 0                   Shape of You        Ed Sheeran       0.58100
# 1                      One Dance             Drake       0.00902
# 2                         Closer  The Chainsmokers       0.41500
# 3  Lean On (feat. MØ & DJ Snake)       Major Lazer       0.00346
# 4              Thinking Out Loud        Ed Sheeran       0.47400
#
#    danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 0         0.825       233713   0.652           0.00000    1    0.0931
# 1         0.785       173987   0.617           0.00246    1    0.3510
# 2         0.736       245507   0.541           0.00000    8    0.1100
# 3         0.723       176561   0.809           0.00123    7    0.5650
# 4         0.781       281560   0.445           0.00000    2    0.1840
#
#    loudness          ...            max_timbre11  range_timbre11  \
# 0    -3.183          ...                -100.251             0.0
# 1    -5.871          ...                -112.977             0.0
# 2    -5.597          ...                -113.259             0.0
# 3    -3.081          ...                 -74.025             0.0
# 4    -6.061          ...                 -90.895             0.0
#
#    80Percentile_timbre11  mean_timbre12  median_timbre12  std_timbre12  \
# 0                 3.6902      -3.411885          -2.4790     13.339611
# 1                 1.6932      -2.246651          -2.4420     15.645132
# 2                 0.6802       1.795072           1.9440     13.292210
# 3                 5.5830       0.437129           1.1040     17.708769
# 4                 6.8418      -6.117562          -5.8825     15.538641
#
#    min_timbre12  max_timbre12  range_timbre12  80Percentile_timbre12
# 0       -53.845       -53.845             0.0                 7.7588
# 1       -44.506       -44.506             0.0                11.5428
# 2       -37.643       -37.643             0.0                12.8920
# 3       -48.071       -48.071             0.0                16.3770
# 4       -57.848       -57.848             0.0                 7.0520
#
# [5 rows x 116 columns]

# %%
# Devide popularity into quantile bins
df['popularity'] = pd.qcut(df['popularity'], 3, labels= False)
df['popularity']
# Out:
# 0      2
# 1      1
# 2      0
# 3      0
# 4      2
# 5      1
# 6      2
# 7      1
# 8      0
# 9      1
# 10     2
# 11     1
# 12     1
# 13     1
# 14     2
# 15     2
# 16     2
# 17     2
# 18     2
# 19     0
# 20     2
# 21     1
# 22     0
# 23     2
# 24     2
# 25     1
# 26     1
# 27     2
# 28     2
# 29     1
#       ..
# 519    1
# 520    2
# 521    2
# 522    2
# 523    2
# 524    1
# 525    2
# 526    2
# 527    2
# 528    2
# 529    2
# 530    1
# 531    1
# 532    2
# 533    1
# 534    0
# 535    0
# 536    1
# 537    0
# 538    2
# 539    1
# 540    1
# 541    1
# 542    2
# 543    1
# 544    1
# 545    0
# 546    1
# 547    0
# 548    2
# Name: popularity, Length: 549, dtype: int64

# %%
# Drop middle quantile to create gap
df_reduced = df[df.popularity!=1]
print('Reduced data set to:')
print(df.shape[0])
# Out:
# Reduced data set to:
# 354

# %%
features = list(df.columns)
features.remove('global')
features.remove('global_100')
features.remove('global_top')
features.remove('popularity')

features.remove('song')
features.remove('artist')
print('Those are our {} features'.format(len(features)))
print(features)
# Out:
# Those are our 110 features
# ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'valence', 'International', 'Unknown', 'electronic', 'folk', 'hip hop', 'house', 'indie', 'latino', 'metal', 'pop', 'punk', 'r&b', 'rap', 'rock', 'mean_timbre1', 'median_timbre1', 'std_timbre1', 'min_timbre1', 'max_timbre1', 'range_timbre1', '80Percentile_timbre1', 'mean_timbre2', 'median_timbre2', 'std_timbre2', 'min_timbre2', 'max_timbre2', 'range_timbre2', '80Percentile_timbre2', 'mean_timbre3', 'median_timbre3', 'std_timbre3', 'min_timbre3', 'max_timbre3', 'range_timbre3', '80Percentile_timbre3', 'mean_timbre4', 'median_timbre4', 'std_timbre4', 'min_timbre4', 'max_timbre4', 'range_timbre4', '80Percentile_timbre4', 'mean_timbre5', 'median_timbre5', 'std_timbre5', 'min_timbre5', 'max_timbre5', 'range_timbre5', '80Percentile_timbre5', 'mean_timbre6', 'median_timbre6', 'std_timbre6', 'min_timbre6', 'max_timbre6', 'range_timbre6', '80Percentile_timbre6', 'mean_timbre7', 'median_timbre7', 'std_timbre7', 'min_timbre7', 'max_timbre7', 'range_timbre7', '80Percentile_timbre7', 'mean_timbre8', 'median_timbre8', 'std_timbre8', 'min_timbre8', 'max_timbre8', 'range_timbre8', '80Percentile_timbre8', 'mean_timbre9', 'median_timbre9', 'std_timbre9', 'min_timbre9', 'max_timbre9', 'range_timbre9', '80Percentile_timbre9', 'mean_timbre10', 'median_timbre10', 'std_timbre10', 'min_timbre10', 'max_timbre10', 'range_timbre10', '80Percentile_timbre10', 'mean_timbre11', 'median_timbre11', 'std_timbre11', 'min_timbre11', 'max_timbre11', 'range_timbre11', '80Percentile_timbre11', 'mean_timbre12', 'median_timbre12', 'std_timbre12', 'min_timbre12', 'max_timbre12', 'range_timbre12', '80Percentile_timbre12']

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ### Define Input/Output

# %%
# Clean dataframe
df_reduced.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0       0.58100         0.825       233713   0.652           0.00000    1
# 2       0.41500         0.736       245507   0.541           0.00000    8
# 3       0.00346         0.723       176561   0.809           0.00123    7
# 4       0.47400         0.781       281560   0.445           0.00000    2
# 6       0.22200         0.630       228827   0.815           0.00000    2
#
#    liveness  loudness  mode  speechiness          ...            max_timbre11  \
# 0    0.0931    -3.183     0       0.0802          ...                -100.251
# 2    0.1100    -5.597     1       0.0297          ...                -113.259
# 3    0.5650    -3.081     0       0.0625          ...                 -74.025
# 4    0.1840    -6.061     1       0.0295          ...                 -90.895
# 6    0.0910    -4.265     1       0.1520          ...                 -76.281
#
#    range_timbre11  80Percentile_timbre11  mean_timbre12  median_timbre12  \
# 0             0.0                 3.6902      -3.411885          -2.4790
# 2             0.0                 0.6802       1.795072           1.9440
# 3             0.0                 5.5830       0.437129           1.1040
# 4             0.0                 6.8418      -6.117562          -5.8825
# 6             0.0                -0.4546      -3.100140          -2.1230
#
#    std_timbre12  min_timbre12  max_timbre12  range_timbre12  \
# 0     13.339611       -53.845       -53.845             0.0
# 2     13.292210       -37.643       -37.643             0.0
# 3     17.708769       -48.071       -48.071             0.0
# 4     15.538641       -57.848       -57.848             0.0
# 6     17.924300       -56.202       -56.202             0.0
#
#    80Percentile_timbre12
# 0                 7.7588
# 2                12.8920
# 3                16.3770
# 4                 7.0520
# 6                10.8952
#
# [5 rows x 110 columns]

# %%
# Input
X= df_reduced[features]
X.head()
print(X.shape)
# Out:
# (354, 110)

# %%
# Normalize Input
from sklearn.preprocessing import normalize
X_norm = normalize(X)

# %%
# Output
Y = df_reduced['popularity']
print(Y.shape)
Y.head()
# Out:
# (354,)
# 0    2
# 2    0
# 3    0
# 4    2
# 6    2
# Name: popularity, dtype: int64

# %%
# Train-Test Split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.15, random_state=100)

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix
def printConfusionMatrix (y_true, y_pred):
    cf=pd.DataFrame(confusion_matrix(y_true, y_pred))
    print(cf)

# %% [markdown]
# ### 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
print('Logistic Regression on popularity: ')
logRegModel = LogisticRegression()
logRegModel.fit(x_train, y_train)
# Accuracy
print('Train Accuracy:')
print(logRegModel.score(x_train, y_train))
print('Test Accuracy:')
print(logRegModel.score(x_test, y_test))
print('Confusion Matrix')
printConfusionMatrix(y_test, logRegModel.predict(x_test))
# Out:
# Logistic Regression on popularity:
# Train Accuracy:
# 0.76
# Test Accuracy:
# 0.6296296296296297
# Confusion Matrix
#     0   1
# 0  21   7
# 1  13  13

# %% [markdown]
# ### 2. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=190)
random_forest.fit(x_train, y_train)
acc_rf1 = random_forest.score(x_train, y_train)
acc_rf2 = random_forest.score(x_test, y_test)
print("Random Forest: ")
print("Training: ", acc_rf1)
print("Test: ", acc_rf2)
print('Confusion Matrix')
printConfusionMatrix(y_test, random_forest.predict(x_test))
# Out:
# Random Forest:
# Training:  1.0
# Test:  0.6111111111111112
# Confusion Matrix
#     0   1
# 0  20   8
# 1  13  13

# %%
values = random_forest.feature_importances_

# %%
dict_featureImportance = dict(zip(features,values))
dict_featureImportance
# Out:
# {'80Percentile_timbre1': 0.010143828054196079,
#  '80Percentile_timbre10': 0.014612247737609559,
#  '80Percentile_timbre11': 0.013582203031201176,
#  '80Percentile_timbre12': 0.008803376214498585,
#  '80Percentile_timbre2': 0.015791411899695927,
#  '80Percentile_timbre3': 0.00856467044941461,
#  '80Percentile_timbre4': 0.012717139108624688,
#  '80Percentile_timbre5': 0.012609825894909788,
#  '80Percentile_timbre6': 0.014090207518668975,
#  '80Percentile_timbre7': 0.013705277511694872,
#  '80Percentile_timbre8': 0.009177696323161962,
#  '80Percentile_timbre9': 0.00903000577666574,
#  'International': 0.0,
#  'Unknown': 0.0009226919090203411,
#  'acousticness': 0.010692262005600646,
#  'danceability': 0.010131567795913947,
#  'duration_ms': 0.008700786405709262,
#  'electronic': 0.0005743822310417693,
#  'energy': 0.01289930360440797,
#  'folk': 0.0,
#  'hip hop': 0.0010690845295793698,
#  'house': 0.001459786490647019,
#  'indie': 0.0005286399912172588,
#  'instrumentalness': 0.009336815718535492,
#  'key': 0.006888747943530758,
#  'latino': 0.005165177711228745,
#  'liveness': 0.012507425727153918,
#  'loudness': 0.007247875521596619,
#  'max_timbre1': 0.011454977970038022,
#  'max_timbre10': 0.009661051696366142,
#  'max_timbre11': 0.012070146075454187,
#  'max_timbre12': 0.014112560549170976,
#  'max_timbre2': 0.007614592965041711,
#  'max_timbre3': 0.010637732987030728,
#  'max_timbre4': 0.009884288359399083,
#  'max_timbre5': 0.009699813916271614,
#  'max_timbre6': 0.01554312759462106,
#  'max_timbre7': 0.009235681399099955,
#  'max_timbre8': 0.017893800608578564,
#  'max_timbre9': 0.010922625063630698,
#  'mean_timbre1': 0.012610216330981618,
#  'mean_timbre10': 0.013393355488879903,
#  'mean_timbre11': 0.0156847205708573,
#  'mean_timbre12': 0.015850746264111117,
#  'mean_timbre2': 0.01902881786910621,
#  'mean_timbre3': 0.00823754920787345,
#  'mean_timbre4': 0.013334525100283177,
#  'mean_timbre5': 0.010148998830381324,
#  'mean_timbre6': 0.012617262118255035,
#  'mean_timbre7': 0.014904065074808783,
#  'mean_timbre8': 0.010796853620886145,
#  'mean_timbre9': 0.00855039014327087,
#  'median_timbre1': 0.010050285460453492,
#  'median_timbre10': 0.010981687799416643,
#  'median_timbre11': 0.020632918645553312,
#  'median_timbre12': 0.00945878741163706,
#  'median_timbre2': 0.024894493036820665,
#  'median_timbre3': 0.009053306143325867,
#  'median_timbre4': 0.011225590751830574,
#  'median_timbre5': 0.009311352427357606,
#  'median_timbre6': 0.013791410504434722,
#  'median_timbre7': 0.010590233892949974,
#  'median_timbre8': 0.012477690465057407,
#  'median_timbre9': 0.007719015990669682,
#  'metal': 0.00016922327940692428,
#  'min_timbre1': 0.01365165969157959,
#  'min_timbre10': 0.011624248504109222,
#  'min_timbre11': 0.011046762912882788,
#  'min_timbre12': 0.013008028388627182,
#  'min_timbre2': 0.007053722130174895,
#  'min_timbre3': 0.010092329895630586,
#  'min_timbre4': 0.010965008174230509,
#  'min_timbre5': 0.00959115161990553,
#  'min_timbre6': 0.014469058558488809,
#  'min_timbre7': 0.009865362926754932,
#  'min_timbre8': 0.01760947900281395,
#  'min_timbre9': 0.011195641108619439,
#  'mode': 0.0015117545722979193,
#  'pop': 0.000593846428165472,
#  'punk': 0.0002910475556572785,
#  'r&b': 0.000631872663104747,
#  'range_timbre1': 0.0,
#  'range_timbre10': 0.0,
#  'range_timbre11': 0.0,
#  'range_timbre12': 0.0,
#  'range_timbre2': 0.0,
#  'range_timbre3': 0.0,
#  'range_timbre4': 0.0,
#  'range_timbre5': 0.0,
#  'range_timbre6': 0.0,
#  'range_timbre7': 0.0,
#  'range_timbre8': 0.0,
#  'range_timbre9': 0.0,
#  'rap': 0.001499286288491926,
#  'rock': 0.0023801613064121352,
#  'speechiness': 0.0130542781089663,
#  'std_timbre1': 0.0,
#  'std_timbre10': 0.014451697872125196,
#  'std_timbre11': 0.014963487304366207,
#  'std_timbre12': 0.009070790167242139,
#  'std_timbre2': 0.010580149334568738,
#  'std_timbre3': 0.009669466817375324,
#  'std_timbre4': 0.01458566046166105,
#  'std_timbre5': 0.01129037379655754,
#  'std_timbre6': 0.01192369086330357,
#  'std_timbre7': 0.013274771956109065,
#  'std_timbre8': 0.017447708902698235,
#  'std_timbre9': 0.010319779549794109,
#  'tempo': 0.014915824250323837,
#  'valence': 0.012175566168125127}

# %%
import operator
sorted_dict = sorted(dict_featureImportance.items(), key=operator.itemgetter(1), reverse = True)
sorted_dict
# Out:
# [('median_timbre2', 0.024894493036820665),
#  ('median_timbre11', 0.020632918645553312),
#  ('mean_timbre2', 0.01902881786910621),
#  ('max_timbre8', 0.017893800608578564),
#  ('min_timbre8', 0.01760947900281395),
#  ('std_timbre8', 0.017447708902698235),
#  ('mean_timbre12', 0.015850746264111117),
#  ('80Percentile_timbre2', 0.015791411899695927),
#  ('mean_timbre11', 0.0156847205708573),
#  ('max_timbre6', 0.01554312759462106),
#  ('std_timbre11', 0.014963487304366207),
#  ('tempo', 0.014915824250323837),
#  ('mean_timbre7', 0.014904065074808783),
#  ('80Percentile_timbre10', 0.014612247737609559),
#  ('std_timbre4', 0.01458566046166105),
#  ('min_timbre6', 0.014469058558488809),
#  ('std_timbre10', 0.014451697872125196),
#  ('max_timbre12', 0.014112560549170976),
#  ('80Percentile_timbre6', 0.014090207518668975),
#  ('median_timbre6', 0.013791410504434722),
#  ('80Percentile_timbre7', 0.013705277511694872),
#  ('min_timbre1', 0.01365165969157959),
#  ('80Percentile_timbre11', 0.013582203031201176),
#  ('mean_timbre10', 0.013393355488879903),
#  ('mean_timbre4', 0.013334525100283177),
#  ('std_timbre7', 0.013274771956109065),
#  ('speechiness', 0.0130542781089663),
#  ('min_timbre12', 0.013008028388627182),
#  ('energy', 0.01289930360440797),
#  ('80Percentile_timbre4', 0.012717139108624688),
#  ('mean_timbre6', 0.012617262118255035),
#  ('mean_timbre1', 0.012610216330981618),
#  ('80Percentile_timbre5', 0.012609825894909788),
#  ('liveness', 0.012507425727153918),
#  ('median_timbre8', 0.012477690465057407),
#  ('valence', 0.012175566168125127),
#  ('max_timbre11', 0.012070146075454187),
#  ('std_timbre6', 0.01192369086330357),
#  ('min_timbre10', 0.011624248504109222),
#  ('max_timbre1', 0.011454977970038022),
#  ('std_timbre5', 0.01129037379655754),
#  ('median_timbre4', 0.011225590751830574),
#  ('min_timbre9', 0.011195641108619439),
#  ('min_timbre11', 0.011046762912882788),
#  ('median_timbre10', 0.010981687799416643),
#  ('min_timbre4', 0.010965008174230509),
#  ('max_timbre9', 0.010922625063630698),
#  ('mean_timbre8', 0.010796853620886145),
#  ('acousticness', 0.010692262005600646),
#  ('max_timbre3', 0.010637732987030728),
#  ('median_timbre7', 0.010590233892949974),
#  ('std_timbre2', 0.010580149334568738),
#  ('std_timbre9', 0.010319779549794109),
#  ('mean_timbre5', 0.010148998830381324),
#  ('80Percentile_timbre1', 0.010143828054196079),
#  ('danceability', 0.010131567795913947),
#  ('min_timbre3', 0.010092329895630586),
#  ('median_timbre1', 0.010050285460453492),
#  ('max_timbre4', 0.009884288359399083),
#  ('min_timbre7', 0.009865362926754932),
#  ('max_timbre5', 0.009699813916271614),
#  ('std_timbre3', 0.009669466817375324),
#  ('max_timbre10', 0.009661051696366142),
#  ('min_timbre5', 0.00959115161990553),
#  ('median_timbre12', 0.00945878741163706),
#  ('instrumentalness', 0.009336815718535492),
#  ('median_timbre5', 0.009311352427357606),
#  ('max_timbre7', 0.009235681399099955),
#  ('80Percentile_timbre8', 0.009177696323161962),
#  ('std_timbre12', 0.009070790167242139),
#  ('median_timbre3', 0.009053306143325867),
#  ('80Percentile_timbre9', 0.00903000577666574),
#  ('80Percentile_timbre12', 0.008803376214498585),
#  ('duration_ms', 0.008700786405709262),
#  ('80Percentile_timbre3', 0.00856467044941461),
#  ('mean_timbre9', 0.00855039014327087),
#  ('mean_timbre3', 0.00823754920787345),
#  ('median_timbre9', 0.007719015990669682),
#  ('max_timbre2', 0.007614592965041711),
#  ('loudness', 0.007247875521596619),
#  ('min_timbre2', 0.007053722130174895),
#  ('key', 0.006888747943530758),
#  ('latino', 0.005165177711228745),
#  ('rock', 0.0023801613064121352),
#  ('mode', 0.0015117545722979193),
#  ('rap', 0.001499286288491926),
#  ('house', 0.001459786490647019),
#  ('hip hop', 0.0010690845295793698),
#  ('Unknown', 0.0009226919090203411),
#  ('r&b', 0.000631872663104747),
#  ('pop', 0.000593846428165472),
#  ('electronic', 0.0005743822310417693),
#  ('indie', 0.0005286399912172588),
#  ('punk', 0.0002910475556572785),
#  ('metal', 0.00016922327940692428),
#  ('International', 0.0),
#  ('folk', 0.0),
#  ('std_timbre1', 0.0),
#  ('range_timbre1', 0.0),
#  ('range_timbre2', 0.0),
#  ('range_timbre3', 0.0),
#  ('range_timbre4', 0.0),
#  ('range_timbre5', 0.0),
#  ('range_timbre6', 0.0),
#  ('range_timbre7', 0.0),
#  ('range_timbre8', 0.0),
#  ('range_timbre9', 0.0),
#  ('range_timbre10', 0.0),
#  ('range_timbre11', 0.0),
#  ('range_timbre12', 0.0)]

# %% [markdown]
# ## Predict global_100

# %%
Y = df_reduced['global_100']
Y.head()
Y.value_counts()
# Out:
# False    217
# True     137
# Name: global_100, dtype: int64

# %%
# Train-Test Split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.15, random_state=100)

# %%
from sklearn.linear_model import LogisticRegression
print('Logistic Regression on global_100: ')
logRegModel = LogisticRegression()
logRegModel.fit(x_train, y_train)
# Accuracy
print('Train Accuracy:')
print(logRegModel.score(x_train, y_train))
print('Test Accuracy:')
print(logRegModel.score(x_test, y_test))
print('Confusion Matrix')
printConfusionMatrix(y_test, logRegModel.predict(x_test))
# Out:
# Logistic Regression on global_100:
# Train Accuracy:
# 0.6966666666666667
# Test Accuracy:
# 0.6481481481481481
# Confusion Matrix
#     0   1
# 0  24   4
# 1  15  11

# %% [markdown]
# ### Predict Overall Success Factor

# %%
a = 10
b = 20
c = 100
Y = df.loc[:,'global']*a+df.global_100*b+df.global_top*c+df.popularity

# %%
Y.head()
# Out:
# 0    132
# 2     30
# 3     30
# 4     32
# 6    132
# dtype: int64
