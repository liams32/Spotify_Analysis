# %%
import spotipy
import spotipy.oauth2
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import numpy as np
import statistics

import time

# %%
CLIENT_ID = '23888f5deee6452db5d78bd2d1091da5'
CLIENT_SECRET = 'f6ecea7a89d24b02b2c969745b88a9db'

client_credentials_manager = SpotifyClientCredentials(CLIENT_ID, CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
dat = pd.read_csv('all_uris.csv', header = None)

# %%
dat.columns = ['index', 'uri']

# %%
dat = dat.drop('index', axis = 'columns')

# %%
new_dat = pd.DataFrame(columns = ['uri'])

# %%
new_dat['uri'] = dat['uri'].unique()

# %%
timbre_mean_labels = ['timbre_mean_1', 'timbre_mean_2', 'timbre_mean_3', 'timbre_mean_4', 
                 'timbre_mean_5', 'timbre_mean_6', 'timbre_mean_7',
                 'timbre_mean_8', 'timbre_mean_9', 'timbre_mean_10', 'timbre_mean_11',
                 'timbre_mean_12']

timbre_median_labels = ['timbre_median_1', 'timbre_median_2', 'timbre_median_3', 'timbre_median_4', 
                 'timbre_median_5', 'timbre_median_6', 'timbre_median_7',
                 'timbre_median_8', 'timbre_median_9', 'timbre_median_10', 'timbre_median_11',
                 'timbre_median_12']

timbre_all_labels = ['timbre_all_1', 'timbre_all_2', 'timbre_all_3', 'timbre_all_4', 
                 'timbre_all_5', 'timbre_all_6', 'timbre_all_7',
                 'timbre_all_8', 'timbre_all_9', 'timbre_all_10', 'timbre_all_11',
                 'timbre_all_12']

timbre_mean_df = pd.DataFrame(columns = timbre_mean_labels)
timbre_median_df = pd.DataFrame(columns = timbre_median_labels)
timbre_all_df = pd.DataFrame(columns = timbre_all_labels)

for i in range(15001, 17501): #iterate through all uris
    start_time = time.time()
    curr_uri = new_dat['uri'][i]
    curr_song = sp.audio_analysis(new_dat['uri'][i])
    curr_segments = curr_song['segments'] #get into segments (time intervals). Each song diff length
    
    init_mean_timbres = pd.Series(np.repeat(0, 12)) #initialize timbre value holder for means
    init_timbres_all = [[] for _ in range(12)] #initialize 12 lists for median (find median each list)
    
    for j in range(0, len(curr_segments)):
        curr_timbres_list = curr_segments[j]['timbre'] #grab timbres as list
        curr_timbres_series = pd.Series(curr_timbres_list) #we have to iterate through every segment
        #print(curr_timbres)
        init_mean_timbres += curr_timbres_series
        
        init_timbres_all[0].append(curr_timbres_list[0])
        init_timbres_all[1].append(curr_timbres_list[1])
        init_timbres_all[2].append(curr_timbres_list[2])
        init_timbres_all[3].append(curr_timbres_list[3])
        init_timbres_all[4].append(curr_timbres_list[4])
        init_timbres_all[5].append(curr_timbres_list[5])
        init_timbres_all[6].append(curr_timbres_list[6])
        init_timbres_all[7].append(curr_timbres_list[7])
        init_timbres_all[8].append(curr_timbres_list[8])
        init_timbres_all[9].append(curr_timbres_list[9])
        init_timbres_all[10].append(curr_timbres_list[10])
        init_timbres_all[11].append(curr_timbres_list[11])
        
    init_mean_timbres = init_mean_timbres / len(curr_segments) #get mean
    timbre_mean_df.loc[i] = init_mean_timbres.values
    
    timbre_median_df.loc[i, 0] = statistics.median(init_timbres_all[0])
    timbre_median_df.loc[i, 1] = statistics.median(init_timbres_all[1])
    timbre_median_df.loc[i, 2] = statistics.median(init_timbres_all[2])
    timbre_median_df.loc[i, 3] = statistics.median(init_timbres_all[3])
    timbre_median_df.loc[i, 4] = statistics.median(init_timbres_all[4])
    timbre_median_df.loc[i, 5] = statistics.median(init_timbres_all[5])
    timbre_median_df.loc[i, 6] = statistics.median(init_timbres_all[6])
    timbre_median_df.loc[i, 7] = statistics.median(init_timbres_all[7])
    timbre_median_df.loc[i, 8] = statistics.median(init_timbres_all[8])
    timbre_median_df.loc[i, 9] = statistics.median(init_timbres_all[9])
    timbre_median_df.loc[i, 10] = statistics.median(init_timbres_all[10])
    timbre_median_df.loc[i, 11] = statistics.median(init_timbres_all[11])
    
    timbre_all_df.at[i, 'timbre_all_1'] = init_timbres_all[0]
    timbre_all_df.at[i, 'timbre_all_2'] = init_timbres_all[1]
    timbre_all_df.at[i, 'timbre_all_3'] = init_timbres_all[2]
    timbre_all_df.at[i, 'timbre_all_4'] = init_timbres_all[3]
    timbre_all_df.at[i, 'timbre_all_5'] = init_timbres_all[4]
    timbre_all_df.at[i, 'timbre_all_6'] = init_timbres_all[5]
    timbre_all_df.at[i, 'timbre_all_7'] = init_timbres_all[6]
    timbre_all_df.at[i, 'timbre_all_8'] = init_timbres_all[7]
    timbre_all_df.at[i, 'timbre_all_9'] = init_timbres_all[8]
    timbre_all_df.at[i, 'timbre_all_10'] = init_timbres_all[9]
    timbre_all_df.at[i, 'timbre_all_11'] = init_timbres_all[10]
    timbre_all_df.at[i, 'timbre_all_12'] = init_timbres_all[11]
    
    print(i, time.time() - start_time)
    #print(timbre_mean_df.tail(2))
# Out:
# 15000 2.253241539001465
# 15001 1.583416223526001
# 15002 1.7544097900390625
# 15003 1.94059157371521
# 15004 2.2517287731170654
# 15005 1.2427539825439453
# 15006 1.2489306926727295
# 15007 2.1445159912109375
# 15008 2.2055647373199463
# 15009 1.1095070838928223
# 15010 1.347952127456665
# 15011 1.739469051361084
# 15012 1.7091774940490723
# 15013 1.6371400356292725
# 15014 1.661393642425537
# 15015 1.224111557006836
# 15016 1.8935070037841797
# 15017 1.7446866035461426
# 15018 2.0629990100860596
# 15019 1.1333489418029785
# 15020 1.7237803936004639
# 15021 1.579254388809204
# 15022 2.817243814468384
# 15023 1.5343801975250244
# 15024 1.7300469875335693
# 15025 1.6766715049743652
# 15026 1.7033579349517822
# 15027 1.6280241012573242
# 15028 1.809786081314087
# 15029 1.7495341300964355
# 15030 1.7338263988494873
# 15031 2.3149123191833496
# 15032 2.267256736755371
# 15033 2.5602033138275146
# 15034 2.9219284057617188
# 15035 2.248007297515869
# 15036 1.9647560119628906
# 15037 2.317056894302368
# 15038 1.7105975151062012
# 15039 2.725008726119995
# 15040 4.236904144287109
# 15041 3.7866060733795166
# 15042 2.922698497772217
# 15043 1.9289131164550781
# 15044 1.7765190601348877
# 15045 2.0075759887695312
# 15046 1.9675829410552979
# 15047 2.4874703884124756
# 15048 2.3778717517852783
# 15049 1.657210111618042
# 15050 1.899301290512085
# 15051 1.7105660438537598
# 15052 3.1696619987487793
# 15053 1.7342193126678467
# 15054 1.7295565605163574
# 15055 2.209252119064331
# 15056 1.6346592903137207
# 15057 1.6002037525177002
# 15058 2.340721607208252
# 15059 1.7634050846099854
# 15060 3.4461638927459717
# 15061 4.670233488082886
# 15062 2.5647668838500977
# 15063 3.164307117462158
# 15064 2.1930432319641113
# 15065 1.845808506011963
# 15066 2.1512668132781982
# 15067 2.8723976612091064
# 15068 1.7258374691009521
# 15069 1.5078380107879639
# 15070 1.9656388759613037
# 15071 2.5714199542999268
# 15072 2.7186837196350098
# 15073 1.6090364456176758
# 15074 2.0644989013671875
# 15075 1.93818998336792
# 15076 2.1161539554595947
# 15077 1.8011550903320312
# 15078 1.9515843391418457
# 15079 2.2584898471832275
# 15080 1.817612648010254
# 15081 1.5333104133605957
# 15082 2.356037139892578
# 15083 1.9668939113616943
# 15084 1.2829606533050537
# 15085 1.2850923538208008
# 15086 2.269334077835083
# 15087 1.5637314319610596
# 15088 2.422992467880249
# 15089 1.5430407524108887
# 15090 2.171417236328125
# 15091 1.8273084163665771
# 15092 2.553987979888916
# 15093 2.5908524990081787
# 15094 2.076674222946167
# 15095 2.3894877433776855
# 15096 1.2325665950775146
# 15097 1.4532337188720703
# 15098 1.4587769508361816
# 15099 1.7080297470092773
# 15100 2.0661604404449463
# 15101 2.045947551727295
# 15102 1.1931183338165283
# 15103 1.8946866989135742
# 15104 1.2940936088562012
# 15105 2.3480403423309326
# 15106 5.518658638000488
# 15107 2.41971755027771
# 15108 2.1583235263824463
# 15109 1.8141999244689941
# 15110 1.58510160446167
# 15111 1.5487480163574219
# 15112 1.4546711444854736
# 15113 1.0966181755065918
# 15114 1.1404528617858887
# 15115 1.0578947067260742
# 15116 1.9663817882537842
# 15117 3.0750555992126465
# 15118 2.857710361480713
# 15119 2.392078399658203
# 15120 2.5315511226654053
# 15121 1.6534297466278076
# 15122 1.112144947052002
# 15123 1.9144001007080078
# 15124 1.5591762065887451
# 15125 1.9211280345916748
# 15126 2.29622745513916
# 15127 1.8313672542572021
# 15128 2.2020061016082764
# 15129 1.4427061080932617
# 15130 2.003143548965454
# 15131 1.9053285121917725
# 15132 2.4541091918945312
# 15133 2.3857994079589844
# 15134 1.568903923034668
# 15135 1.7080702781677246
# 15136 1.80450439453125
# 15137 2.774412155151367
# 15138 1.9529829025268555
# 15139 1.4750828742980957
# 15140 2.252300262451172
# 15141 2.49192476272583
# 15142 1.7674641609191895
# 15143 3.072988986968994
# 15144 1.3554956912994385
# 15145 1.2396745681762695
# 15146 1.7841300964355469
# 15147 1.4318437576293945
# 15148 1.4955928325653076
# 15149 1.8558976650238037
# 15150 1.3739755153656006
# 15151 2.352168083190918
# 15152 1.809859275817871
# 15153 1.0629549026489258
# 15154 1.9826374053955078
# 15155 1.6865744590759277
# 15156 1.6783359050750732
# 15157 1.7722878456115723
# 15158 1.6011908054351807
# 15159 2.558823585510254
# 15160 2.3381268978118896
# 15161 2.592590808868408
# 15162 1.929112195968628
# 15163 1.9657881259918213
# 15164 2.4543569087982178
# 15165 2.276787757873535
# 15166 2.2613143920898438
# 15167 2.606348991394043
# 15168 2.1385629177093506
# 15169 1.8648438453674316
# 15170 1.8823745250701904
# 15171 1.6635968685150146
# 15172 4.642555236816406
# 15173 2.017699956893921
# 15174 1.735231637954712
# 15175 1.9574012756347656
# 15176 2.1094624996185303
# 15177 1.9184229373931885
# 15178 2.1006765365600586
# 15179 1.8309829235076904
# 15180 2.630897283554077
# 15181 1.5128443241119385
