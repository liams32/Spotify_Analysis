# %%
import spotipy
import spotipy.oauth2
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import numpy as np
import statistics
import matplotlib.pyplot as plt
import time

# %matplotlib inline

# %%
dat = pd.read_csv('just_uris.csv', header = None, names = ['some_index', 'uri'])

# %%
dat.head(2)
# Out:
#    some_index                                   uri
# 0           0  spotify:track:7pueb0FHOYlKAJPXhVhwml
# 1           1  spotify:track:4pLwZjInHj3SimIyN9SnOz

# %%
CLIENT_ID = '23888f5deee6452db5d78bd2d1091da5'
CLIENT_SECRET = 'f6ecea7a89d24b02b2c969745b88a9db'

client_credentials_manager = SpotifyClientCredentials(CLIENT_ID, CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
blah = sp.track(dat['uri'][0]) #dummy data

# %%
blah['popularity'] #dummy data
# Out:
# 61

# %%
dat['popularity'] = ''

# %%
def f(row):
    # %%time
    return(sp.track(row)['popularity'])

# %%
# %%time
dat['popularity'] = dat['uri'].apply(f)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 8.82 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 11 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 13.6 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 12.9 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 12.9 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 13.6 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 9.54 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 11 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 13.4 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 13.1 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 13.4 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 7.87 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 9.54 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 8.82 µs
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# ...

# %%
dat.head(2)
# Out:
#    some_index                                   uri  popularity
# 0           0  spotify:track:7pueb0FHOYlKAJPXhVhwml          61
# 1           1  spotify:track:4pLwZjInHj3SimIyN9SnOz          80

# %%
dat = dat.drop('some_index', axis = 'columns')

# %%
dat.to_csv('uri_with_popularity_subset.csv')
