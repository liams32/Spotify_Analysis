# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
# %matplotlib inline

# %%
dat_0_50 = pd.read_csv('dat_0_50.csv')
dat_50_100 = pd.read_csv('dat_50_100.csv')
dat_100_150 = pd.read_csv('dat_100_150.csv')
dat_150_200 = pd.read_csv('dat_150_200.csv')

# %%
print(dat_0_50.shape)
print(dat_50_100.shape)
print(dat_100_150.shape)
print(dat_150_200.shape)
# Out:
# (50, 19)
# (50, 19)
# (50, 19)
# (50, 19)

# %%
name_num_stream = pd.read_csv('regional-global-weekly-latest.csv')

# %%
name_num_stream.head(2)
# Out:
#    Position                Track Name          Artist   Streams  \
# 0         1                God's Plan           Drake  53416337
# 1         2  All The Stars (with SZA)  Kendrick Lamar  30168080
#
#                                                  URL
# 0  https://open.spotify.com/track/2XW4DbS6NddZxRP...
# 1  https://open.spotify.com/track/2Imq77E6CEJR5TP...

# %%
dat_0_200 = pd.concat([dat_0_50, dat_50_100, dat_100_150, dat_150_200])
dat_0_200.rename(columns = {'Unnamed: 0':'rank'}, inplace = True)
#dat_0_200['rank'] = pd.Series(range(1, 201))

# %%
print(dat_0_200.shape)
dat_0_200.head(2)
# Out:
# (200, 19)
#    rank  acousticness                                       analysis_url  \
# 0     0        0.0244  https://api.spotify.com/v1/audio-analysis/2XW4...
# 1     1        0.0548  https://api.spotify.com/v1/audio-analysis/2Imq...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.753       198960   0.454  2XW4DbS6NddZxRPm5rMCeY
# 1         0.532       232187   0.642  2Imq77E6CEJR5TPUxlJvTY
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000056    7    0.4980    -9.488     1       0.0963   77.170
# 1          0.000246    5    0.0991    -4.891     0       0.1110  193.016
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/2XW4DbS6NddZ...
# 1               4  https://api.spotify.com/v1/tracks/2Imq77E6CEJR...
#
#              type                                   uri  valence
# ...

# %%
dat_0_200.index = range(0, 200)

# %%
final = pd.concat([name_num_stream, dat_0_200], axis=1, join='outer', ignore_index=False)

print(final.shape)
final.head(3)
# Out:
# (200, 24)
#    Position                Track Name          Artist   Streams  \
# 0         1                God's Plan           Drake  53416337
# 1         2  All The Stars (with SZA)  Kendrick Lamar  30168080
# 2         3                      Mine           Bazzi  23666856
#
#                                                  URL  rank  acousticness  \
# 0  https://open.spotify.com/track/2XW4DbS6NddZxRP...     0        0.0244
# 1  https://open.spotify.com/track/2Imq77E6CEJR5TP...     1        0.0548
# 2  https://open.spotify.com/track/6tHWl8ows5JOZq9...     2        0.0140
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/2XW4...         0.753
# 1  https://api.spotify.com/v1/audio-analysis/2Imq...         0.532
# 2  https://api.spotify.com/v1/audio-analysis/6tHW...         0.716
#
#    duration_ms   ...     liveness loudness  mode  speechiness    tempo  \
# ...

# %%
final.to_csv('all_data.csv')
